# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('cars.csv')

# %%
df
# Out:
#         brand  km_driven    fuel                 owner  selling_price
# 0      Maruti     145500  Diesel           First Owner         450000
# 1       Skoda     120000  Diesel          Second Owner         370000
# 2       Honda     140000  Petrol           Third Owner         158000
# 3     Hyundai     127000  Diesel           First Owner         225000
# 4      Maruti     120000  Petrol           First Owner         130000
# ...       ...        ...     ...                   ...            ...
# 8123  Hyundai     110000  Petrol           First Owner         320000
# 8124  Hyundai     119000  Diesel  Fourth & Above Owner         135000
# 8125   Maruti     120000  Diesel           First Owner         382000
# 8126     Tata      25000  Diesel           First Owner         290000
# 8127     Tata      25000  Diesel           First Owner         290000
#
# [8128 rows x 5 columns]

# %%
df['owner'].value_counts()

# it shows that in owner coulmn, which value is occur how many times
# Out:
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
df['fuel'].value_counts()
# Out:
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: fuel, dtype: int64

# %% [markdown]
# # 1. One Hot Encoding Using Pandas

# %%
pd.get_dummies(df,columns=['fuel','owner'])

# this will encode the mentioned columns, like there were 4 categories of fuel & 5 of owner , so total 5+4+3(reamining)
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000         0            1         0
# 1       Skoda     120000         370000         0            1         0
# 2       Honda     140000         158000         0            0         0
# 3     Hyundai     127000         225000         0            1         0
# 4      Maruti     120000         130000         0            0         0
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000         0            0         0
# 8124  Hyundai     119000         135000         0            1         0
# 8125   Maruti     120000         382000         0            1         0
# 8126     Tata      25000         290000         0            1         0
# 8127     Tata      25000         290000         0            1         0
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# # 2. K-1 One Hot Encoding

# %%
pd.get_dummies(df,columns=['fuel','owner'], drop_first=True)

# it will drop the first columns of those columns which were encoded or mentioned,like for fuel & owner 1st column droped
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000            1         0            0
# 1       Skoda     120000         370000            1         0            0
# 2       Honda     140000         158000            0         0            1
# 3     Hyundai     127000         225000            1         0            0
# 4      Maruti     120000         130000            0         0            1
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000            0         0            1
# 8124  Hyundai     119000         135000            1         0            0
# 8125   Maruti     120000         382000            1         0            0
# 8126     Tata      25000         290000            1         0            0
# 8127     Tata      25000         290000            1         0            0
#
# ...

# %% [markdown]
# # 3. One Hot Encoding using SKlearn

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.3,random_state=0)

# it will split the original data

# %%
X_train.head()
# Out:
#           brand  km_driven    fuel        owner
# 5224       Tata      20000  Petrol  First Owner
# 520      Maruti      30000  Petrol  First Owner
# 36       Maruti      15000  Petrol  First Owner
# 5782       Ford      53000  Diesel  First Owner
# 6522  Chevrolet     120000  Diesel  First Owner

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
oe=OneHotEncoder(drop='first',sparse_output=False,dtype=np.int32)

# %%
X_train_new= oe.fit_transform(X_train[['fuel','owner']])
X_test_new= oe.transform(X_test[['fuel','owner']])

# we are transforming the fuel & owner columns

# %%
X_train_new.shape
# Out:
# (5689, 7)

# %%
np.hstack((X_train[['brand','km_driven']].values,X_train_new))
# Out:
# array([['Tata', 20000, 0, ..., 0, 0, 0],
#        ['Maruti', 30000, 0, ..., 0, 0, 0],
#        ['Maruti', 15000, 0, ..., 0, 0, 0],
#        ...,
#        ['Hyundai', 90000, 0, ..., 1, 0, 0],
#        ['Volkswagen', 90000, 1, ..., 0, 0, 0],
#        ['Hyundai', 110000, 0, ..., 0, 0, 0]], dtype=object)

# %% [markdown]
# # 4. One Hot Encoding with Top Categories

# %%
counts=df['brand'].value_counts()

# %%
counts
# Out:
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: brand, dtype: int64

# %%
df['brand'].nunique()
# Out:
# 32

# %%
df['brand'].nunique()
threshold = 100

# %%
repl = counts[counts <= threshold].index

# becoz there were many no. of categories of brand, so we conert all those brands which have made cars less than 100 in one
#  column called other

# %%
pd.get_dummies(df['brand'].replace(repl, 'uncommon')).sample(5)
# Out:
#       BMW  Chevrolet  Ford  Honda  Hyundai  Mahindra  Maruti  Renault  Skoda  \
# 7441    0          0     0      1        0         0       0        0      0
# 3477    0          0     1      0        0         0       0        0      0
# 4219    0          0     0      0        0         0       0        0      0
# 7364    0          0     0      0        0         0       1        0      0
# 2957    0          0     0      0        1         0       0        0      0
#
#       Tata  Toyota  Volkswagen  uncommon
# 7441     0       0           0         0
# 3477     0       0           0         0
# 4219     0       0           0         1
# 7364     0       0           0         0
# 2957     0       0           0         0
